# %%
from rlaopt.preconditioners.sketches.gauss import Gauss
from rlaopt.preconditioners.sketches.sparse import Sparse
import torch
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from rlaopt.preconditioners.sketches.gauss import Gauss
#       2 from rlaopt.preconditioners.sketches.sparse import Sparse
#       3 import torch
#
# File ~/rlaopt/rlaopt/preconditioners/__init__.py:1
# ----> 1 from rlaopt.preconditioners.preconditioner import Preconditioner
#       2 from rlaopt.preconditioners.identity import Identity
#       3 from rlaopt.preconditioners.nystrom import Nystrom
#
# File ~/rlaopt/rlaopt/preconditioners/preconditioner.py:6
#       2 from typing import Union
#       4 import torch
# ----> 6 from rlaopt.models import LinOp
#       7 from rlaopt.preconditioners.configs import PreconditionerConfig
#      10 class Preconditioner(ABC):
#
# File ~/rlaopt/rlaopt/models/__init__.py:2
#       1 from rlaopt.models.linops import LinOp, TwoSidedLinOp, SymmetricLinOp
# ----> 2 from rlaopt.models.linsys import LinSys
#       4 __all__ = ["LinOp", "TwoSidedLinOp", "SymmetricLinOp", "LinSys"]
#
# File ~/rlaopt/rlaopt/models/linsys.py:5
#       1 from typing import Callable, Union, Optional
#       3 import torch
# ----> 5 from rlaopt.models.model import Model
#       6 from rlaopt.models.linops import LinOp
#       7 from rlaopt.solvers import PCG, _is_solver_config
#
# File ~/rlaopt/rlaopt/models/model.py:7
#       3 from warnings import warn
#       5 import torch
# ----> 7 from rlaopt.solvers import SolverConfig, Solver
#       8 from rlaopt.utils import Logger
#      11 class Model(ABC):
#
# File ~/rlaopt/rlaopt/solvers/__init__.py:2
#       1 from rlaopt.solvers.solver import Solver
# ----> 2 from rlaopt.solvers.pcg import PCG
#       3 from rlaopt.solvers.configs import SolverConfig, PCGConfig, _is_solver_config
#       5 __all__ = ["Solver", "PCG", "SolverConfig", "PCGConfig", "_is_solver_config"]
#
# File ~/rlaopt/rlaopt/solvers/pcg.py:6
#       3 import torch
#       5 from rlaopt.solvers.solver import Solver
# ----> 6 from rlaopt.preconditioners import Nystrom, Identity
#       7 from rlaopt.preconditioners import (
#       8     PreconditionerConfig,
#       9     NystromConfig,
#      10     IdentityConfig,
#      11 )
#      13 if TYPE_CHECKING:
#
# ImportError: cannot import name 'Nystrom' from partially initialized module 'rlaopt.preconditioners' (most likely due to a circular import) (/home/zfran/rlaopt/rlaopt/preconditioners/__init__.py)
